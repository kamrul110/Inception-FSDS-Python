# %% [markdown]
# #Assignment 1: Temperature Check
# Problem:
# Write a program that takes the current temperature as input and prints:
# ● "It's too cold!" if below 10°C
# ● "It's cool outside" if between 10°C and 25°C
# ● "It's hot outside!" if above 25°C

# %%
# Assignment 1 ans
temperature = float(input("Enter the current temperature (°C):"))
if temperature < 10:
    print('its too cold')
elif temperature >= 10 and temperature <=25:
    print("It's cool outside")
else:
    print("It's hot outside!")
# Out:
# It's cool outside

# %% [markdown]
# Assignment 2: ATM Withdrawal System
# Problem:
# Ask the user for their account balance and the amount they want to withdraw.
# ● If the withdrawal amount is greater than the balance → print "Insufficient
# Balance"
# ● If the withdrawal amount is less than or equal to balance → print "Transaction
# Successful" and show the remaining balance.

# %%
# Assignment 2 ans
balance = float(input('enter the account balance:'))
withdraw = float(input('amount withdraw: '))
if balance >= withdraw:
    amount= balance-withdraw
    print('Transaction Successful. Remaining balance:',amount)
    
else:
    print('Insufficient Balance')
# Out:
# Transaction Successful. 10.0

# %% [markdown]
# Assignment 3: Student Grade Calculator
# Problem:
# Input marks (0–100) and print grade based on:
# ● 90–100 → A+
# ● 80–89 → A
# ● 70–79 → B
# ● 60–69 → C
# ● Below 60 → Fail

# %%
# Assignment 3 ans
marks = float(input('Enter the number: '))
if(marks >= 90 and marks <= 100):
    print('You got A+')
elif(marks >=80 and marks <=89):
    print('You got A')
elif(marks >=70 and marks <= 79):
    print('you got B')
elif( marks >=60 and marks <= 69):
    print('you got C')
elif(marks < 60):
    print('you got fail')
else:
    print('Enter a valid number between 0 and 100')
# Out:
# you got C.your mark is: 60.0

# %% [markdown]
# Assignment 4: Bus Ticket Discount
# Problem:
# Ask the user for age and print ticket price:
# ● Below 5 → Free
# ● 5–18 → 50% Discount
# ● 60 or above → 30% Discount
# ● Others → Full Price

# %%
# Assignment 4 ans
age = int(input('Enter age:'))
if age < 5:
    print('Free')
elif age >= 5 and age <= 18:
    print("you got 50% discount") 
elif age >= 60:
    print('30% discount')
else:
    print('full price')
# Out:
# you got 50% discount

# %% [markdown]
# Assignment 5: Restaurant Bill with Discount
# Problem:
# Take total bill amount from the user:
# ● If the bill is above 1000 → apply 10% discount
# ● Otherwise → no discount
# Then print the final bill amount.

# %%
bill = float(input('Enter bill amount:'))
if bill >= 1000:
    amount = bill*10/100
    finalBill = bill-amount
    print('you got 10% discount. Final bill amount:',finalBill)
else:
    print('no discount',bill)
# Out:
# you got 10% discount 1080.0

# %% [markdown]
# Assignment 6: Login Authentication
# Problem:
# Take a username and password input.
# ● If username == "admin" and password == "12345" → print "Login Successful"
# ● Else → print "Invalid Credentials"

# %%
# Assignment 6 ans
username = (input('Enter your username:'))
password= (input('Enter your password:')) 
actual_username = 'admin'
actual_password = '12345'
if username == actual_username and password == actual_password:
    print('Login Successful')
else:
    print('Invalid Credentials')
# Out:
# Login Successful

# %% [markdown]
# Assignment 7: Traffic Light System
# Problem:
# Ask the user to input a color (red, yellow, or green).
# Print:
# ● "Stop" for red
# ● "Ready to go" for yellow
# ● "Go" for green
# ● "Invalid color" otherwise

# %%
color = input('Enter color:')
color1= 'red'
color2 = 'yellow'
color3 = 'green'
if color == color1:
    print('Stop')
elif color == color2:
    print("Ready to go")
elif color == color3:
    print('Go')
else:
    print('Invalid color')
# Out:
# Stop

# %% [markdown]
# Assignment 8: Leap Year Checker
# Problem:
# Take a year as input and check:
# ● If it is divisible by 400 → Leap Year
# ● Else if divisible by 4 but not by 100 → Leap Year
# ● Otherwise → Not a Leap Year

# %%
# Assignment 8 ans
year= int(input('enter year'))
if year % 400==0:
    print('leap year')
elif year % 4 ==0 and year % 100 !=0 :
    print('leap year')
else:
    print('Not a Leap Year')
# Out:
# Not a Leap Year

# %% [markdown]
# Assignment 9: Job Eligibility Checker
# Problem:
# Input age and qualification.
# ● If age ≥ 18 and qualification is “graduate” → print "Eligible for Job"
# ● Else → "Not Eligible"

# %%
age = int(input('enter age:'))
qualification = input('enter qualification:')
if age >= 18 and qualification == 'graduate':
    print('Eligible for Job')
else:
    print('Not Eligible')
# Out:
# Eligible for Job

# %% [markdown]
# Assignment 10: Electricity Bill Calculator
# Problem:
# Input number of units consumed and calculate bill:
# ● Up to 100 units → 5 BDT per unit
# ● 101–200 units → 7 BDT per unit
# ● Above 200 units → 10 BDT per unit
# Print total payable amount.

# %%
# Assignment 10 ans
number_of_units = float(input('Enter number of units:'))

if number_of_units <= 100:
    total= number_of_units * 5
    print('5 BDT per unit',total)
elif  number_of_units <=200:
    total= number_of_units * 7
    print('7 BDT per unit',total)
else:
    total= number_of_units * 10
    print('10 BDT per unit',total)
# Out:
# 5 BDT per unit 500.0
